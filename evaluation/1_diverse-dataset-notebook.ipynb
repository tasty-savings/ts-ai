# %% [markdown]
# # MongoDB에서 모든 레시피를 가져와 데이터 전처리

# %%
import os
import sys

# src 폴더 경로를 Python 경로에 추가
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src')))

from db import MongoDB 
import pandas as pd

def get_recipes_and_save_to_csv():
    """
    MongoDB에서 모든 레시피를 가져와 CSV로 저장
    """
    with MongoDB() as mongo_db:
        try:
            collection_name = "recipe"  # MongoDB 컬렉션 이름
            projection = {
                "title": 1, "type_key": 1, "method_key": 1,
                "servings": 1, "cooking_time": 1,
                "ingredients": 1, "cooking_steps": 1,
                "difficulty": 1, "tips": 1, "recipe_type": 1
            }
            
            print("레시피 데이터를 가져오는 중...")
            # limit 없이 모든 문서 가져오기
            recipes = mongo_db.find_many(collection_name, {}, projection)

            # 데이터프레임으로 변환
            print("데이터프레임 변환 중...")
            recipes_list = [dict(recipe) for recipe in recipes]
            for recipe in recipes_list:
                recipe['_id'] = str(recipe['_id'])  # ObjectId를 문자열로 변환

            df = pd.DataFrame(recipes_list)
            print(f"변환된 데이터 크기: {len(df)}행 x {len(df.columns)}열")
            
            # CSV 파일 저장 경로
            csv_file_path = os.path.join(os.getcwd(), "data/all_recipeinfo_dataset.csv")
            df.to_csv(csv_file_path, index=False)
            print(f"레시피 데이터를 {csv_file_path}에 저장했습니다.")
            
            # 데이터 검증
            print(df.info())
            print("\n=== 데이터 검증 ===")
            print("Type key 분포:")
            print(df['type_key'].value_counts())
            print("\nMethod key 분포:")
            print(df['method_key'].value_counts())
            print("\nServings 분포:")
            print(df['servings'].value_counts())
            
        except Exception as e:
            print(f"get_recipes_and_save_to_csv() 오류 발생: {e}")
        
        return df
df_recipes = get_recipes_and_save_to_csv()
# Out:
# 레시피 데이터를 가져오는 중...
# find_many 호출됨 - 컬렉션: recipe, limit: None
# 데이터프레임 변환 중...
# 변환된 데이터 크기: 17788행 x 11열
# 레시피 데이터를 /Users/minji/workspace/ts-ai/evaluation/data/all_recipeinfo_dataset.csv에 저장했습니다.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17788 entries, 0 to 17787
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            17788 non-null  object
#  1   title          17788 non-null  object
#  2   type_key       17788 non-null  object
#  3   method_key     17788 non-null  object
#  4   servings       17788 non-null  object
#  5   cooking_time   17788 non-null  object
#  6   difficulty     17788 non-null  object
#  7   ingredients    17788 non-null  object
#  8   cooking_steps  17788 non-null  object
#  9   tips           17788 non-null  object
#  10  recipe_type    17788 non-null  object
# dtypes: object(11)
# memory usage: 1.5+ MB
# None
#
# === 데이터 검증 ===
# Type key 분포:
# type_key
# 반찬         9064
# 밥/죽/떡       887
# 국/찌개        877
# 양식          845
# 면/만두        842
# 빵/과자        835
# 샐러드         830
# 디저트         812
# 스프          781
# 퓨전          776
# 양념/잼/소스     771
# 차/음료/술      468
# Name: count, dtype: int64
#
# Method key 분포:
# method_key
# 끓이기    3463
# 볶음     3015
# 굽기     2715
# 부침     1851
# 무침     1830
# 조림     1728
# 찜      1179
# 튀김      754
# 절임      516
# 비빔      397
# 삶기      276
# 회        43
# 갈기       21
# Name: count, dtype: int64
#
# Servings 분포:
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64

# %% [markdown]
# ## 데이터 전처리 & 분포 확인 함수 생성
# - 매운맛 관련 컬럼 생성
# - servings 이상값 고치기

# %%
import re

def detect_spicy_level(recipe_type):
    """
    레시피 타입에서 매운맛 단계를 검출하는 함수
    매운맛이 없으면 '매운맛없음' 반환
    """
    if isinstance(recipe_type, str):
        # 문자열이 들어온 경우 리스트로 변환
        try:
            recipe_type = eval(recipe_type)
        except:
            return "매운맛없음"
    
    if not isinstance(recipe_type, list):
        return "형식지정이상함"
        
    # 매운맛 단계 검출
    spicy_pattern = r'매운맛(\d)단계'
    for type_item in recipe_type:
        match = re.search(spicy_pattern, str(type_item))
        if match:
            return f"매운맛{match.group(1)}단계"
    
    return "매운맛없음"
df_recipes['spicy_level'] = df_recipes['recipe_type'].apply(detect_spicy_level)
df_recipes.spicy_level.value_counts()
# Out:
# spicy_level
# 매운맛없음     12820
# 매운맛1단계     4504
# 매운맛2단계      370
# 매운맛3단계       63
# 매운맛4단계       27
# 매운맛5단계        4
# Name: count, dtype: int64

# %%
# print("servings 컬럼의 데이터 타입:", df_recipes['servings'].dtype)
def fix_servings(df_recipes):
    # 문자열 값을 기반으로 변경
    mapping = {
        '': '  ',
        '1': '1인분',
        '2': '2인분',
        '4': '4인분',
        '5': '5인분',
        1: '1인분',    # 혹시 숫자 타입이 섞여 있을 경우를 대비
        2: '2인분',
        4: '4인분',
        5: '5인분'
    }

    # 변경 전 확인
    print("변경 전:")
    print(df_recipes['servings'].value_counts())

    # 값 변경
    df_recipes['servings'] = df_recipes['servings'].replace(mapping)

    # 변경 후 확인
    print("\n변경 후:")
    print(df_recipes['servings'].value_counts())
    df_recipes.info()

    return df_recipes

# df_recipes = fix_servings(df_recipes)
# Out:
# 변경 전:
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
#
# 변경 후:
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17788 entries, 0 to 17787
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            17788 non-null  object
#  1   title          17788 non-null  object
#  2   type_key       17788 non-null  object
#  3   method_key     17788 non-null  object
#  4   servings       17788 non-null  object
#  5   cooking_time   17788 non-null  object
#  6   difficulty     17788 non-null  object
#  7   ingredients    17788 non-null  object
#  8   cooking_steps  17788 non-null  object
#  9   tips           17788 non-null  object
#  10  recipe_type    17788 non-null  object
#  11  spicy_level    17788 non-null  object
# dtypes: object(12)
# memory usage: 1.6+ MB

# %%
def print_distribution(df_recipes: pd.DataFrame):
    print("=== Type Key 분포 ===")
    print(df_recipes['type_key'].value_counts())
    print(len(df_recipes['type_key'].value_counts()))
    print("\n=== Method Key 분포 ===")
    print(df_recipes['method_key'].value_counts())
    print(len(df_recipes['method_key'].value_counts()))
    print("\n=== Servings 분포 ===")
    print(df_recipes['servings'].value_counts())
    print(len(df_recipes['servings'].value_counts()))
    print("\n=== 매운맛 단계 분포 ===")
    print(df_recipes['spicy_level'].value_counts())
    print(len(df_recipes['spicy_level'].value_counts()))
print_distribution(df_recipes)
# Out:
# === Type Key 분포 ===
# type_key
# 반찬         9064
# 밥/죽/떡       887
# 국/찌개        877
# 양식          845
# 면/만두        842
# 빵/과자        835
# 샐러드         830
# 디저트         812
# 스프          781
# 퓨전          776
# 양념/잼/소스     771
# 차/음료/술      468
# Name: count, dtype: int64
# 12
#
# === Method Key 분포 ===
# method_key
# 끓이기    3463
# 볶음     3015
# 굽기     2715
# 부침     1851
# 무침     1830
# 조림     1728
# 찜      1179
# 튀김      754
# 절임      516
# 비빔      397
# 삶기      276
# 회        43
# 갈기       21
# Name: count, dtype: int64
# 13
#
# === Servings 분포 ===
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
# 6
#
# === 매운맛 단계 분포 ===
# spicy_level
# 매운맛없음     12820
# 매운맛1단계     4504
# 매운맛2단계      370
# 매운맛3단계       63
# 매운맛4단계       27
# 매운맛5단계        4
# Name: count, dtype: int64
# 6

# %% [markdown]
# ## 다음 함수들 적용한 것을 새롭게 csv로 저장
# - df_recipes = get_recipes_and_save_to_csv() : mongodb에서 데이터 가져와서 csv에 저장
# - df_recipes = fix_servings(df_recipes) : dataset에서 servings 이상한 것 고침
# - df_recipes['spicy_level'] = df_recipes['recipe_type'].apply(detect_spicy_level) : 매운맛 단계 추출해서 컬럼 만듦

# %%
df_recipes.to_csv("data/all_recipeinfo_dataset.csv", index=False)
print_distribution(df_recipes)
# Out:
# === Type Key 분포 ===
# type_key
# 반찬         9064
# 밥/죽/떡       887
# 국/찌개        877
# 양식          845
# 면/만두        842
# 빵/과자        835
# 샐러드         830
# 디저트         812
# 스프          781
# 퓨전          776
# 양념/잼/소스     771
# 차/음료/술      468
# Name: count, dtype: int64
# 12
#
# === Method Key 분포 ===
# method_key
# 끓이기    3463
# 볶음     3015
# 굽기     2715
# 부침     1851
# 무침     1830
# 조림     1728
# 찜      1179
# 튀김      754
# 절임      516
# 비빔      397
# 삶기      276
# 회        43
# 갈기       21
# Name: count, dtype: int64
# 13
#
# === Servings 분포 ===
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
# 6
#
# === 매운맛 단계 분포 ===
# spicy_level
# 매운맛없음     12820
# 매운맛1단계     4504
# 매운맛2단계      370
# 매운맛3단계       63
# 매운맛4단계       27
# 매운맛5단계        4
# Name: count, dtype: int64
# 6

# %% [markdown]
# # 다양한 레시피 데이터셋 생성
# type_key, method_key, servings가 다양하게 분포된 테스트용 데이터셋을 생성합니다.

# %%
import pandas as pd

# 원본 데이터 로드
df = pd.read_csv("data/all_recipeinfo_dataset.csv")
df.describe()
# Out:
#                              _id     title type_key method_key servings  \
# count                      17788     17788    17788      17788    17113
# unique                     17788     17335       12         13        5
# top     67610699846f9e5eb975e332  돼지고기 장조림       반찬        끓이기      2인분
# freq                           1        14     9064       3463     6784
#
#        cooking_time difficulty  \
# count         16228      16690
# unique            9          3
# top          30분 이내         초급
# freq           6331      15517
#
#                                               ingredients  \
# count                                               17788
# unique                                              17713
# top     ['닭(1팩)', '우유(3컵)', '간장(2T)', '간 마늘(2T)', '굴소스...
# freq                                                    3
#
#                                             cooking_steps   tips  \
# count                                               17788  17788
# unique                                              17781   8649
# top     ['바쁜아침 시간도 절약되고금방 만들어서 바로 먹을 수 있는깻잎찜 소개 시켜 드릴께...     []
# freq                                                    2   8942
#
#                       recipe_type spicy_level
# count                       17788       17788
# unique                       8846           6
# top     ['고단백', '한식', '반찬', '조림']       매운맛없음
# freq                          197       12820

# %%
print_distribution(df_recipes)
# Out:
# === Type Key 분포 ===
# type_key
# 반찬         9064
# 밥/죽/떡       887
# 국/찌개        877
# 양식          845
# 면/만두        842
# 빵/과자        835
# 샐러드         830
# 디저트         812
# 스프          781
# 퓨전          776
# 양념/잼/소스     771
# 차/음료/술      468
# Name: count, dtype: int64
# 12
#
# === Method Key 분포 ===
# method_key
# 끓이기    3463
# 볶음     3015
# 굽기     2715
# 부침     1851
# 무침     1830
# 조림     1728
# 찜      1179
# 튀김      754
# 절임      516
# 비빔      397
# 삶기      276
# 회        43
# 갈기       21
# Name: count, dtype: int64
# 13
#
# === Servings 분포 ===
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
# 6
#
# === 매운맛 단계 분포 ===
# spicy_level
# 매운맛없음     12820
# 매운맛1단계     4504
# 매운맛2단계      370
# 매운맛3단계       63
# 매운맛4단계       27
# 매운맛5단계        4
# Name: count, dtype: int64
# 6

# %% [markdown]
# ## 2-1. 다양한 레시피 선택 함수 정의
# - 각 컬럼의 값이 하나씩은 꼭 있어야할 때, 35개 나옴(중복 상관 없을 경우)

# %%
from collections import Counter

def get_diverse_recipes(df, n_samples=100):
    """
    type_key, method_key, servings, spicy_level이 다양하게 분포된 레시피 데이터셋을 생성.
    중복 제거를 하며 n_samples 이상을 확보할 때까지 반복.
    
    Parameters:
    df: 원본 레시피 DataFrame
    n_samples: 목표 샘플 수
    
    Returns:
    DataFrame: 선택된 레시피들
    """
    selected_indices = set()

    while True:
        # 분포 계산
        type_dist = Counter(df['type_key'])
        method_dist = Counter(df['method_key'])
        servings_dist = Counter(df['servings'])
        spicy_dist = Counter(df['spicy_level'])

        # 각 카테고리별 최소 샘플 수 계산
        min_type_samples = max(1, n_samples // len(type_dist))
        min_method_samples = max(1, n_samples // len(method_dist))
        min_servings_samples = max(1, n_samples // len(servings_dist))
        min_spicy_samples = max(1, n_samples // len(spicy_dist))

        # 1. 각 spicy_level에서 최소 샘플 확보
        for spicy_level in spicy_dist.keys():
            spicy_recipes = df[df['spicy_level'] == spicy_level]
            remaining = spicy_recipes[~spicy_recipes.index.isin(selected_indices)]
            if len(remaining) >= min_spicy_samples:
                selected = remaining.sample(n=min_spicy_samples).index
                selected_indices.update(selected)

        # 2. 각 type_key에서 최소 샘플 확보
        for type_key in type_dist.keys():
            type_recipes = df[df['type_key'] == type_key]
            remaining = type_recipes[~type_recipes.index.isin(selected_indices)]
            if len(remaining) >= min_type_samples:
                selected = remaining.sample(n=min_type_samples).index
                selected_indices.update(selected)

        # 3. 각 method_key에서 최소 샘플 확보
        for method_key in method_dist.keys():
            method_recipes = df[df['method_key'] == method_key]
            remaining = method_recipes[~method_recipes.index.isin(selected_indices)]
            if len(remaining) >= min_method_samples:
                selected = remaining.sample(n=min_method_samples).index
                selected_indices.update(selected)

        # 4. 각 servings에서 최소 샘플 확보
        for servings in servings_dist.keys():
            servings_recipes = df[df['servings'] == servings]
            remaining = servings_recipes[~servings_recipes.index.isin(selected_indices)]
            if len(remaining) >= min_servings_samples:
                selected = remaining.sample(n=min_servings_samples).index
                selected_indices.update(selected)

        # 중복 제거된 결과 생성
        diverse_recipes = df.loc[list(selected_indices)].drop_duplicates(
            subset=['type_key', 'method_key', 'servings', 'spicy_level'], keep='first'
        )

        # 종료 조건: n_samples 이상의 행이 확보되면 종료
        if len(diverse_recipes) >= n_samples:
            break

    return diverse_recipes

# 함수 실행
df_sample = get_diverse_recipes(df, n_samples=10)
df_sample.describe()
# Out:
#                              _id  title type_key method_key servings  \
# count                         35     35       35         35       34
# unique                        35     35       12         13        5
# top     67610699846f9e5eb975e532  연어샐러드       반찬        끓이기      1인분
# freq                           1      1       10         10       12
#
#        cooking_time difficulty  \
# count            33         33
# unique            7          2
# top          30분 이내         초급
# freq             14         29
#
#                                               ingredients  \
# count                                                  35
# unique                                                 35
# top     ['연어(150g)', '레몬(1/4개)', '발사믹식초(50g)', '어린잎채소(...
# freq                                                    1
#
#                                             cooking_steps tips  \
# count                                                  35   35
# unique                                                 35   17
# top     ['1. 연어는 깍둑썰기한다.', '2. 썰어 놓은 연어는 후춧가루와 레몬으로 마리...   []
# freq                                                    1   19
#
#                           recipe_type spicy_level
# count                              35          35
# unique                             35           6
# top     ['고단백', '저칼로리', '해산물', '샐러드']       매운맛없음
# freq                                1          23

# %% [markdown]
# ### 2-2. 다양한 레시피 선택 함수 정의
#
# - `show_all_combinations` 함수 : 가능한 모든 조합 확인
#
# **통계**
# - 전체 조합 수: 5616
# - 실제 존재 조합 수: 987
# - 비율: 17.57%
#
# **카테고리별 unique 값 수**
# - `type_key`: 12
# - `method_key`: 13
# - `servings`: 6
# - `spicy_level`: 6

# %%
# 가능한 모든 조합 확인
def show_all_combinations(df):
    # servings 컬럼의 데이터 타입을 문자열로 통일
    df_copy = df.copy()
    df_copy['servings'] = df_copy['servings'].astype(str)
    
    # 1. 각 컬럼의 unique 값들을 가져옵니다
    type_keys = sorted(df_copy['type_key'].unique())
    method_keys = sorted(df_copy['method_key'].unique())
    servings_values = sorted(df_copy['servings'].unique())
    spicy_levels = sorted(df_copy['spicy_level'].unique())
    
    # 2. 실제 존재하는 조합을 저장
    existing_combinations = set(
        df_copy.groupby(['type_key', 'method_key', 'servings', 'spicy_level'])
        .size()
        .index
    )
    
    # 3. 모든 가능한 조합을 생성하고 확인
    print("모든 가능한 조합:")
    print("\n{:<10} {:<10} {:<8} {:<12} {:<10}".format(
        'type_key', 'method_key', 'servings', 'spicy_level', 'exists'
    ))
    print("-" * 60)
    
    total_combinations = 0
    existing_count = 0
    
    for type_k in type_keys:
        for method_k in method_keys:
            for serv in servings_values:
                for spicy in spicy_levels:
                    combination = (type_k, method_k, serv, spicy)
                    exists = combination in existing_combinations
                    
                    print("{:<10} {:<10} {:<8} {:<12} {:<10}".format(
                        type_k, method_k, serv, spicy, 
                        "O" if exists else "X"
                    ))
                    
                    total_combinations += 1
                    if exists:
                        existing_count += 1
    
    # 4. 통계 출력
    print("\n통계:")
    print(f"전체 가능한 조합 수: {total_combinations}")
    print(f"실제 존재하는 조합 수: {existing_count}")
    print(f"비율: {(existing_count/total_combinations)*100:.2f}%")
    
    # 5. 각 카테고리별 값의 수 출력
    print("\n각 카테고리별 unique 값의 수:")
    print(f"type_key: {len(type_keys)} 개")
    print(f"method_key: {len(method_keys)} 개")
    print(f"servings: {len(servings_values)} 개")
    print(f"spicy_level: {len(spicy_levels)} 개")
    
    return {
        'total_combinations': total_combinations,
        'existing_combinations': existing_count,
        'type_keys': type_keys,
        'method_keys': method_keys,
        'servings_values': servings_values,
        'spicy_levels': spicy_levels
    }

# 함수 실행
combinations_info = show_all_combinations(df)
# Out:
# 모든 가능한 조합:
#
# type_key   method_key servings spicy_level  exists
# ------------------------------------------------------------
# 국/찌개       갈기         1인분      매운맛1단계       X
# 국/찌개       갈기         1인분      매운맛2단계       X
# 국/찌개       갈기         1인분      매운맛3단계       X
# 국/찌개       갈기         1인분      매운맛4단계       X
# 국/찌개       갈기         1인분      매운맛5단계       X
# 국/찌개       갈기         1인분      매운맛없음        O
# 국/찌개       갈기         2인분      매운맛1단계       X
# 국/찌개       갈기         2인분      매운맛2단계       X
# 국/찌개       갈기         2인분      매운맛3단계       X
# 국/찌개       갈기         2인분      매운맛4단계       X
# 국/찌개       갈기         2인분      매운맛5단계       X
# 국/찌개       갈기         2인분      매운맛없음        X
# 국/찌개       갈기         3인분      매운맛1단계       X
# 국/찌개       갈기         3인분      매운맛2단계       X
# 국/찌개       갈기         3인분      매운맛3단계       X
# 국/찌개       갈기         3인분      매운맛4단계       X
# 국/찌개       갈기         3인분      매운맛5단계       X
# 국/찌개       갈기         3인분      매운맛없음        X
# 국/찌개       갈기         4인분      매운맛1단계       X
# 국/찌개       갈기         4인분      매운맛2단계       X
# 국/찌개       갈기         4인분      매운맛3단계       X
# 국/찌개       갈기         4인분      매운맛4단계       X
# 국/찌개       갈기         4인분      매운맛5단계       X
# 국/찌개       갈기         4인분      매운맛없음        X
# 국/찌개       갈기         5인분      매운맛1단계       X
# 국/찌개       갈기         5인분      매운맛2단계       X
# 국/찌개       갈기         5인분      매운맛3단계       X
# 국/찌개       갈기         5인분      매운맛4단계       X
# 국/찌개       갈기         5인분      매운맛5단계       X
# 국/찌개       갈기         5인분      매운맛없음        X
# 국/찌개       갈기         nan      매운맛1단계       X
# 국/찌개       갈기         nan      매운맛2단계       X
# 국/찌개       갈기         nan      매운맛3단계       X
# 국/찌개       갈기         nan      매운맛4단계       X
# 국/찌개       갈기         nan      매운맛5단계       X
# 국/찌개       갈기         nan      매운맛없음        X
# 국/찌개       굽기         1인분      매운맛1단계       X
# 국/찌개       굽기         1인분      매운맛2단계       X
# 국/찌개       굽기         1인분      매운맛3단계       X
# 국/찌개       굽기         1인분      매운맛4단계       X
# 국/찌개       굽기         1인분      매운맛5단계       X
# 국/찌개       굽기         1인분      매운맛없음        X
# 국/찌개       굽기         2인분      매운맛1단계       X
# 국/찌개       굽기         2인분      매운맛2단계       X
# 국/찌개       굽기         2인분      매운맛3단계       X
# 국/찌개       굽기         2인분      매운맛4단계       X
# 국/찌개       굽기         2인분      매운맛5단계       X
# 국/찌개       굽기         2인분      매운맛없음        X
# 국/찌개       굽기         3인분      매운맛1단계       X
# 국/찌개       굽기         3인분      매운맛2단계       X
# 국/찌개       굽기         3인분      매운맛3단계       X
# 국/찌개       굽기         3인분      매운맛4단계       X
# 국/찌개       굽기         3인분      매운맛5단계       X
# 국/찌개       굽기         3인분      매운맛없음        O
# 국/찌개       굽기         4인분      매운맛1단계       X
# 국/찌개       굽기         4인분      매운맛2단계       X
# 국/찌개       굽기         4인분      매운맛3단계       X
# 국/찌개       굽기         4인분      매운맛4단계       X
# 국/찌개       굽기         4인분      매운맛5단계       X
# 국/찌개       굽기         4인분      매운맛없음        X
# 국/찌개       굽기         5인분      매운맛1단계       X
# 국/찌개       굽기         5인분      매운맛2단계       X
# 국/찌개       굽기         5인분      매운맛3단계       X
# 국/찌개       굽기         5인분      매운맛4단계       X
# 국/찌개       굽기         5인분      매운맛5단계       X
# 국/찌개       굽기         5인분      매운맛없음        X
# 국/찌개       굽기         nan      매운맛1단계       X
# 국/찌개       굽기         nan      매운맛2단계       X
# 국/찌개       굽기         nan      매운맛3단계       X
# 국/찌개       굽기         nan      매운맛4단계       X
# 국/찌개       굽기         nan      매운맛5단계       X
# 국/찌개       굽기         nan      매운맛없음        X
# 국/찌개       끓이기        1인분      매운맛1단계       O
# 국/찌개       끓이기        1인분      매운맛2단계       O
# 국/찌개       끓이기        1인분      매운맛3단계       O
# 국/찌개       끓이기        1인분      매운맛4단계       X
# 국/찌개       끓이기        1인분      매운맛5단계       X
# 국/찌개       끓이기        1인분      매운맛없음        O
# 국/찌개       끓이기        2인분      매운맛1단계       O
# 국/찌개       끓이기        2인분      매운맛2단계       O
# 국/찌개       끓이기        2인분      매운맛3단계       O
# 국/찌개       끓이기        2인분      매운맛4단계       X
# 국/찌개       끓이기        2인분      매운맛5단계       X
# 국/찌개       끓이기        2인분      매운맛없음        O
# 국/찌개       끓이기        3인분      매운맛1단계       O
# 국/찌개       끓이기        3인분      매운맛2단계       O
# 국/찌개       끓이기        3인분      매운맛3단계       O
# 국/찌개       끓이기        3인분      매운맛4단계       X
# 국/찌개       끓이기        3인분      매운맛5단계       X
# 국/찌개       끓이기        3인분      매운맛없음        O
# 국/찌개       끓이기        4인분      매운맛1단계       O
# 국/찌개       끓이기        4인분      매운맛2단계       O
# 국/찌개       끓이기        4인분      매운맛3단계       O
# 국/찌개       끓이기        4인분      매운맛4단계       X
# 국/찌개       끓이기        4인분      매운맛5단계       X
# 국/찌개       끓이기        4인분      매운맛없음        O
# 국/찌개       끓이기        5인분      매운맛1단계       O
# 국/찌개       끓이기        5인분      매운맛2단계       O
# 국/찌개       끓이기        5인분      매운맛3단계       O
# 국/찌개       끓이기        5인분      매운맛4단계       X
# 국/찌개       끓이기        5인분      매운맛5단계       X
# 국/찌개       끓이기        5인분      매운맛없음        O
# 국/찌개       끓이기        nan      매운맛1단계       O
# 국/찌개       끓이기        nan      매운맛2단계       O
# 국/찌개       끓이기        nan      매운맛3단계       O
# 국/찌개       끓이기        nan      매운맛4단계       O
# 국/찌개       끓이기        nan      매운맛5단계       X
# 국/찌개       끓이기        nan      매운맛없음        O
# 국/찌개       무침         1인분      매운맛1단계       X
# 국/찌개       무침         1인분      매운맛2단계       X
# 국/찌개       무침         1인분      매운맛3단계       X
# 국/찌개       무침         1인분      매운맛4단계       X
# 국/찌개       무침         1인분      매운맛5단계       X
# 국/찌개       무침         1인분      매운맛없음        X
# 국/찌개       무침         2인분      매운맛1단계       O
# 국/찌개       무침         2인분      매운맛2단계       X
# 국/찌개       무침         2인분      매운맛3단계       X
# 국/찌개       무침         2인분      매운맛4단계       X
# 국/찌개       무침         2인분      매운맛5단계       X
# 국/찌개       무침         2인분      매운맛없음        O
# 국/찌개       무침         3인분      매운맛1단계       X
# 국/찌개       무침         3인분      매운맛2단계       X
# 국/찌개       무침         3인분      매운맛3단계       X
# 국/찌개       무침         3인분      매운맛4단계       X
# 국/찌개       무침         3인분      매운맛5단계       X
# 국/찌개       무침         3인분      매운맛없음        X
# 국/찌개       무침         4인분      매운맛1단계       X
# 국/찌개       무침         4인분      매운맛2단계       X
# 국/찌개       무침         4인분      매운맛3단계       X
# 국/찌개       무침         4인분      매운맛4단계       X
# 국/찌개       무침         4인분      매운맛5단계       X
# 국/찌개       무침         4인분      매운맛없음        X
# 국/찌개       무침         5인분      매운맛1단계       X
# 국/찌개       무침         5인분      매운맛2단계       X
# 국/찌개       무침         5인분      매운맛3단계       X
# 국/찌개       무침         5인분      매운맛4단계       X
# 국/찌개       무침         5인분      매운맛5단계       X
# 국/찌개       무침         5인분      매운맛없음        X
# 국/찌개       무침         nan      매운맛1단계       X
# 국/찌개       무침         nan      매운맛2단계       X
# 국/찌개       무침         nan      매운맛3단계       X
# 국/찌개       무침         nan      매운맛4단계       X
# 국/찌개       무침         nan      매운맛5단계       X
# 국/찌개       무침         nan      매운맛없음        X
# 국/찌개       볶음         1인분      매운맛1단계       X
# 국/찌개       볶음         1인분      매운맛2단계       X
# 국/찌개       볶음         1인분      매운맛3단계       X
# 국/찌개       볶음         1인분      매운맛4단계       X
# 국/찌개       볶음         1인분      매운맛5단계       X
# 국/찌개       볶음         1인분      매운맛없음        X
# 국/찌개       볶음         2인분      매운맛1단계       X
# 국/찌개       볶음         2인분      매운맛2단계       X
# 국/찌개       볶음         2인분      매운맛3단계       O
# 국/찌개       볶음         2인분      매운맛4단계       X
# 국/찌개       볶음         2인분      매운맛5단계       X
# 국/찌개       볶음         2인분      매운맛없음        X
# 국/찌개       볶음         3인분      매운맛1단계       O
# 국/찌개       볶음         3인분      매운맛2단계       O
# 국/찌개       볶음         3인분      매운맛3단계       X
# 국/찌개       볶음         3인분      매운맛4단계       X
# 국/찌개       볶음         3인분      매운맛5단계       X
# 국/찌개       볶음         3인분      매운맛없음        X
# 국/찌개       볶음         4인분      매운맛1단계       O
# 국/찌개       볶음         4인분      매운맛2단계       X
# 국/찌개       볶음         4인분      매운맛3단계       X
# 국/찌개       볶음         4인분      매운맛4단계       X
# 국/찌개       볶음         4인분      매운맛5단계       X
# 국/찌개       볶음         4인분      매운맛없음        X
# 국/찌개       볶음         5인분      매운맛1단계       X
# 국/찌개       볶음         5인분      매운맛2단계       X
# 국/찌개       볶음         5인분      매운맛3단계       X
# 국/찌개       볶음         5인분      매운맛4단계       X
# 국/찌개       볶음         5인분      매운맛5단계       X
# 국/찌개       볶음         5인분      매운맛없음        X
# 국/찌개       볶음         nan      매운맛1단계       X
# 국/찌개       볶음         nan      매운맛2단계       X
# 국/찌개       볶음         nan      매운맛3단계       X
# 국/찌개       볶음         nan      매운맛4단계       X
# 국/찌개       볶음         nan      매운맛5단계       X
# 국/찌개       볶음         nan      매운맛없음        X
# 국/찌개       부침         1인분      매운맛1단계       X
# 국/찌개       부침         1인분      매운맛2단계       X
# 국/찌개       부침         1인분      매운맛3단계       X
# 국/찌개       부침         1인분      매운맛4단계       X
# 국/찌개       부침         1인분      매운맛5단계       X
# 국/찌개       부침         1인분      매운맛없음        X
# 국/찌개       부침         2인분      매운맛1단계       X
# 국/찌개       부침         2인분      매운맛2단계       X
# 국/찌개       부침         2인분      매운맛3단계       X
# 국/찌개       부침         2인분      매운맛4단계       X
# 국/찌개       부침         2인분      매운맛5단계       X
# 국/찌개       부침         2인분      매운맛없음        O
# 국/찌개       부침         3인분      매운맛1단계       X
# 국/찌개       부침         3인분      매운맛2단계       X
# 국/찌개       부침         3인분      매운맛3단계       X
# 국/찌개       부침         3인분      매운맛4단계       X
# 국/찌개       부침         3인분      매운맛5단계       X
# 국/찌개       부침         3인분      매운맛없음        X
# 국/찌개       부침         4인분      매운맛1단계       X
# 국/찌개       부침         4인분      매운맛2단계       X
# 국/찌개       부침         4인분      매운맛3단계       X
# 국/찌개       부침         4인분      매운맛4단계       X
# 국/찌개       부침         4인분      매운맛5단계       X
# 국/찌개       부침         4인분      매운맛없음        X
# 국/찌개       부침         5인분      매운맛1단계       X
# 국/찌개       부침         5인분      매운맛2단계       X
# 국/찌개       부침         5인분      매운맛3단계       X
# 국/찌개       부침         5인분      매운맛4단계       X
# 국/찌개       부침         5인분      매운맛5단계       X
# 국/찌개       부침         5인분      매운맛없음        X
# 국/찌개       부침         nan      매운맛1단계       X
# 국/찌개       부침         nan      매운맛2단계       X
# 국/찌개       부침         nan      매운맛3단계       X
# 국/찌개       부침         nan      매운맛4단계       X
# 국/찌개       부침         nan      매운맛5단계       X
# 국/찌개       부침         nan      매운맛없음        X
# 국/찌개       비빔         1인분      매운맛1단계       X
# 국/찌개       비빔         1인분      매운맛2단계       X
# 국/찌개       비빔         1인분      매운맛3단계       X
# 국/찌개       비빔         1인분      매운맛4단계       X
# 국/찌개       비빔         1인분      매운맛5단계       X
# 국/찌개       비빔         1인분      매운맛없음        X
# 국/찌개       비빔         2인분      매운맛1단계       X
# 국/찌개       비빔         2인분      매운맛2단계       X
# 국/찌개       비빔         2인분      매운맛3단계       X
# 국/찌개       비빔         2인분      매운맛4단계       X
# 국/찌개       비빔         2인분      매운맛5단계       X
# 국/찌개       비빔         2인분      매운맛없음        X
# 국/찌개       비빔         3인분      매운맛1단계       X
# 국/찌개       비빔         3인분      매운맛2단계       X
# 국/찌개       비빔         3인분      매운맛3단계       X
# 국/찌개       비빔         3인분      매운맛4단계       X
# 국/찌개       비빔         3인분      매운맛5단계       X
# 국/찌개       비빔         3인분      매운맛없음        X
# 국/찌개       비빔         4인분      매운맛1단계       X
# 국/찌개       비빔         4인분      매운맛2단계       X
# 국/찌개       비빔         4인분      매운맛3단계       X
# 국/찌개       비빔         4인분      매운맛4단계       X
# 국/찌개       비빔         4인분      매운맛5단계       X
# 국/찌개       비빔         4인분      매운맛없음        X
# 국/찌개       비빔         5인분      매운맛1단계       X
# 국/찌개       비빔         5인분      매운맛2단계       X
# 국/찌개       비빔         5인분      매운맛3단계       X
# 국/찌개       비빔         5인분      매운맛4단계       X
# 국/찌개       비빔         5인분      매운맛5단계       X
# 국/찌개       비빔         5인분      매운맛없음        X
# 국/찌개       비빔         nan      매운맛1단계       X
# 국/찌개       비빔         nan      매운맛2단계       X
# 국/찌개       비빔         nan      매운맛3단계       X
# 국/찌개       비빔         nan      매운맛4단계       X
# 국/찌개       비빔         nan      매운맛5단계       X
# 국/찌개       비빔         nan      매운맛없음        X
# 국/찌개       삶기         1인분      매운맛1단계       X
# 국/찌개       삶기         1인분      매운맛2단계       X
# 국/찌개       삶기         1인분      매운맛3단계       X
# 국/찌개       삶기         1인분      매운맛4단계       X
# 국/찌개       삶기         1인분      매운맛5단계       X
# 국/찌개       삶기         1인분      매운맛없음        X
# 국/찌개       삶기         2인분      매운맛1단계       X
# 국/찌개       삶기         2인분      매운맛2단계       X
# 국/찌개       삶기         2인분      매운맛3단계       X
# 국/찌개       삶기         2인분      매운맛4단계       X
# 국/찌개       삶기         2인분      매운맛5단계       X
# 국/찌개       삶기         2인분      매운맛없음        X
# 국/찌개       삶기         3인분      매운맛1단계       O
# 국/찌개       삶기         3인분      매운맛2단계       X
# 국/찌개       삶기         3인분      매운맛3단계       X
# 국/찌개       삶기         3인분      매운맛4단계       X
# 국/찌개       삶기         3인분      매운맛5단계       X
# 국/찌개       삶기         3인분      매운맛없음        O
# 국/찌개       삶기         4인분      매운맛1단계       O
# 국/찌개       삶기         4인분      매운맛2단계       X
# 국/찌개       삶기         4인분      매운맛3단계       X
# 국/찌개       삶기         4인분      매운맛4단계       X
# 국/찌개       삶기         4인분      매운맛5단계       X
# 국/찌개       삶기         4인분      매운맛없음        X
# 국/찌개       삶기         5인분      매운맛1단계       X
# 국/찌개       삶기         5인분      매운맛2단계       X
# 국/찌개       삶기         5인분      매운맛3단계       X
# 국/찌개       삶기         5인분      매운맛4단계       X
# 국/찌개       삶기         5인분      매운맛5단계       X
# 국/찌개       삶기         5인분      매운맛없음        X
# 국/찌개       삶기         nan      매운맛1단계       X
# 국/찌개       삶기         nan      매운맛2단계       X
# 국/찌개       삶기         nan      매운맛3단계       X
# 국/찌개       삶기         nan      매운맛4단계       X
# 국/찌개       삶기         nan      매운맛5단계       X
# 국/찌개       삶기         nan      매운맛없음        X
# 국/찌개       절임         1인분      매운맛1단계       X
# 국/찌개       절임         1인분      매운맛2단계       X
# 국/찌개       절임         1인분      매운맛3단계       X
# 국/찌개       절임         1인분      매운맛4단계       X
# 국/찌개       절임         1인분      매운맛5단계       X
# 국/찌개       절임         1인분      매운맛없음        X
# 국/찌개       절임         2인분      매운맛1단계       X
# 국/찌개       절임         2인분      매운맛2단계       X
# 국/찌개       절임         2인분      매운맛3단계       X
# 국/찌개       절임         2인분      매운맛4단계       X
# 국/찌개       절임         2인분      매운맛5단계       X
# 국/찌개       절임         2인분      매운맛없음        X
# 국/찌개       절임         3인분      매운맛1단계       X
# 국/찌개       절임         3인분      매운맛2단계       X
# 국/찌개       절임         3인분      매운맛3단계       X
# 국/찌개       절임         3인분      매운맛4단계       X
# 국/찌개       절임         3인분      매운맛5단계       X
# 국/찌개       절임         3인분      매운맛없음        X
# 국/찌개       절임         4인분      매운맛1단계       X
# 국/찌개       절임         4인분      매운맛2단계       X
# 국/찌개       절임         4인분      매운맛3단계       X
# 국/찌개       절임         4인분      매운맛4단계       X
# 국/찌개       절임         4인분      매운맛5단계       X
# 국/찌개       절임         4인분      매운맛없음        X
# 국/찌개       절임         5인분      매운맛1단계       X
# 국/찌개       절임         5인분      매운맛2단계       X
# 국/찌개       절임         5인분      매운맛3단계       X
# 국/찌개       절임         5인분      매운맛4단계       X
# 국/찌개       절임         5인분      매운맛5단계       X
# 국/찌개       절임         5인분      매운맛없음        X
# 국/찌개       절임         nan      매운맛1단계       X
# 국/찌개       절임         nan      매운맛2단계       X
# 국/찌개       절임         nan      매운맛3단계       X
# 국/찌개       절임         nan      매운맛4단계       X
# 국/찌개       절임         nan      매운맛5단계       X
# 국/찌개       절임         nan      매운맛없음        X
# 국/찌개       조림         1인분      매운맛1단계       X
# 국/찌개       조림         1인분      매운맛2단계       X
# 국/찌개       조림         1인분      매운맛3단계       X
# 국/찌개       조림         1인분      매운맛4단계       X
# 국/찌개       조림         1인분      매운맛5단계       X
# 국/찌개       조림         1인분      매운맛없음        X
# 국/찌개       조림         2인분      매운맛1단계       O
# 국/찌개       조림         2인분      매운맛2단계       O
# 국/찌개       조림         2인분      매운맛3단계       X
# 국/찌개       조림         2인분      매운맛4단계       X
# 국/찌개       조림         2인분      매운맛5단계       X
# 국/찌개       조림         2인분      매운맛없음        O
# 국/찌개       조림         3인분      매운맛1단계       O
# 국/찌개       조림         3인분      매운맛2단계       O
# 국/찌개       조림         3인분      매운맛3단계       X
# 국/찌개       조림         3인분      매운맛4단계       X
# 국/찌개       조림         3인분      매운맛5단계       X
# 국/찌개       조림         3인분      매운맛없음        X
# 국/찌개       조림         4인분      매운맛1단계       O
# 국/찌개       조림         4인분      매운맛2단계       X
# 국/찌개       조림         4인분      매운맛3단계       X
# 국/찌개       조림         4인분      매운맛4단계       X
# 국/찌개       조림         4인분      매운맛5단계       X
# 국/찌개       조림         4인분      매운맛없음        O
# 국/찌개       조림         5인분      매운맛1단계       X
# 국/찌개       조림         5인분      매운맛2단계       X
# 국/찌개       조림         5인분      매운맛3단계       X
# 국/찌개       조림         5인분      매운맛4단계       X
# 국/찌개       조림         5인분      매운맛5단계       X
# 국/찌개       조림         5인분      매운맛없음        X
# 국/찌개       조림         nan      매운맛1단계       X
# 국/찌개       조림         nan      매운맛2단계       O
# 국/찌개       조림         nan      매운맛3단계       X
# 국/찌개       조림         nan      매운맛4단계       X
# 국/찌개       조림         nan      매운맛5단계       X
# 국/찌개       조림         nan      매운맛없음        X
# 국/찌개       찜          1인분      매운맛1단계       X
# 국/찌개       찜          1인분      매운맛2단계       X
# 국/찌개       찜          1인분      매운맛3단계       X
# 국/찌개       찜          1인분      매운맛4단계       X
# 국/찌개       찜          1인분      매운맛5단계       X
# 국/찌개       찜          1인분      매운맛없음        O
# 국/찌개       찜          2인분      매운맛1단계       O
# 국/찌개       찜          2인분      매운맛2단계       X
# 국/찌개       찜          2인분      매운맛3단계       X
# 국/찌개       찜          2인분      매운맛4단계       X
# 국/찌개       찜          2인분      매운맛5단계       X
# 국/찌개       찜          2인분      매운맛없음        O
# 국/찌개       찜          3인분      매운맛1단계       O
# 국/찌개       찜          3인분      매운맛2단계       X
# 국/찌개       찜          3인분      매운맛3단계       X
# 국/찌개       찜          3인분      매운맛4단계       X
# 국/찌개       찜          3인분      매운맛5단계       X
# 국/찌개       찜          3인분      매운맛없음        X
# 국/찌개       찜          4인분      매운맛1단계       O
# 국/찌개       찜          4인분      매운맛2단계       X
# 국/찌개       찜          4인분      매운맛3단계       X
# 국/찌개       찜          4인분      매운맛4단계       X
# 국/찌개       찜          4인분      매운맛5단계       X
# 국/찌개       찜          4인분      매운맛없음        X
# 국/찌개       찜          5인분      매운맛1단계       X
# 국/찌개       찜          5인분      매운맛2단계       X
# 국/찌개       찜          5인분      매운맛3단계       X
# 국/찌개       찜          5인분      매운맛4단계       X
# 국/찌개       찜          5인분      매운맛5단계       X
# 국/찌개       찜          5인분      매운맛없음        O
# 국/찌개       찜          nan      매운맛1단계       X
# 국/찌개       찜          nan      매운맛2단계       X
# 국/찌개       찜          nan      매운맛3단계       X
# 국/찌개       찜          nan      매운맛4단계       X
# 국/찌개       찜          nan      매운맛5단계       X
# 국/찌개       찜          nan      매운맛없음        X
# 국/찌개       튀김         1인분      매운맛1단계       X
# 국/찌개       튀김         1인분      매운맛2단계       X
# 국/찌개       튀김         1인분      매운맛3단계       X
# 국/찌개       튀김         1인분      매운맛4단계       X
# 국/찌개       튀김         1인분      매운맛5단계       X
# 국/찌개       튀김         1인분      매운맛없음        X
# 국/찌개       튀김         2인분      매운맛1단계       X
# 국/찌개       튀김         2인분      매운맛2단계       O
# 국/찌개       튀김         2인분      매운맛3단계       X
# 국/찌개       튀김         2인분      매운맛4단계       X
# 국/찌개       튀김         2인분      매운맛5단계       X
# 국/찌개       튀김         2인분      매운맛없음        X
# 국/찌개       튀김         3인분      매운맛1단계       X
# 국/찌개       튀김         3인분      매운맛2단계       X
# 국/찌개       튀김         3인분      매운맛3단계       X
# 국/찌개       튀김         3인분      매운맛4단계       X
# 국/찌개       튀김         3인분      매운맛5단계       X
# 국/찌개       튀김         3인분      매운맛없음        X
# 국/찌개       튀김         4인분      매운맛1단계       X
# 국/찌개       튀김         4인분      매운맛2단계       X
# 국/찌개       튀김         4인분      매운맛3단계       X
# 국/찌개       튀김         4인분      매운맛4단계       X
# 국/찌개       튀김         4인분      매운맛5단계       X
# 국/찌개       튀김         4인분      매운맛없음        X
# 국/찌개       튀김         5인분      매운맛1단계       X
# 국/찌개       튀김         5인분      매운맛2단계       X
# 국/찌개       튀김         5인분      매운맛3단계       X
# 국/찌개       튀김         5인분      매운맛4단계       X
# 국/찌개       튀김         5인분      매운맛5단계       X
# 국/찌개       튀김         5인분      매운맛없음        X
# 국/찌개       튀김         nan      매운맛1단계       X
# 국/찌개       튀김         nan      매운맛2단계       X
# 국/찌개       튀김         nan      매운맛3단계       X
# 국/찌개       튀김         nan      매운맛4단계       X
# 국/찌개       튀김         nan      매운맛5단계       X
# 국/찌개       튀김         nan      매운맛없음        X
# 국/찌개       회          1인분      매운맛1단계       X
# 국/찌개       회          1인분      매운맛2단계       X
# 국/찌개       회          1인분      매운맛3단계       X
# 국/찌개       회          1인분      매운맛4단계       X
# 국/찌개       회          1인분      매운맛5단계       X
# 국/찌개       회          1인분      매운맛없음        X
# 국/찌개       회          2인분      매운맛1단계       X
# 국/찌개       회          2인분      매운맛2단계       X
# 국/찌개       회          2인분      매운맛3단계       X
# 국/찌개       회          2인분      매운맛4단계       X
# 국/찌개       회          2인분      매운맛5단계       X
# 국/찌개       회          2인분      매운맛없음        X
# 국/찌개       회          3인분      매운맛1단계       X
# 국/찌개       회          3인분      매운맛2단계       X
# 국/찌개       회          3인분      매운맛3단계       X
# 국/찌개       회          3인분      매운맛4단계       X
# 국/찌개       회          3인분      매운맛5단계       X
# 국/찌개       회          3인분      매운맛없음        X
# 국/찌개       회          4인분      매운맛1단계       X
# 국/찌개       회          4인분      매운맛2단계       X
# 국/찌개       회          4인분      매운맛3단계       X
# 국/찌개       회          4인분      매운맛4단계       X
# 국/찌개       회          4인분      매운맛5단계       X
# 국/찌개       회          4인분      매운맛없음        X
# 국/찌개       회          5인분      매운맛1단계       X
# 국/찌개       회          5인분      매운맛2단계       X
# 국/찌개       회          5인분      매운맛3단계       X
# 국/찌개       회          5인분      매운맛4단계       X
# 국/찌개       회          5인분      매운맛5단계       X
# 국/찌개       회          5인분      매운맛없음        X
# 국/찌개       회          nan      매운맛1단계       X
# 국/찌개       회          nan      매운맛2단계       X
# 국/찌개       회          nan      매운맛3단계       X
# 국/찌개       회          nan      매운맛4단계       X
# 국/찌개       회          nan      매운맛5단계       X
# 국/찌개       회          nan      매운맛없음        X
# 디저트        갈기         1인분      매운맛1단계       X
# 디저트        갈기         1인분      매운맛2단계       X
# 디저트        갈기         1인분      매운맛3단계       X
# 디저트        갈기         1인분      매운맛4단계       X
# 디저트        갈기         1인분      매운맛5단계       X
# 디저트        갈기         1인분      매운맛없음        O
# 디저트        갈기         2인분      매운맛1단계       X
# 디저트        갈기         2인분      매운맛2단계       X
# 디저트        갈기         2인분      매운맛3단계       X
# 디저트        갈기         2인분      매운맛4단계       X
# 디저트        갈기         2인분      매운맛5단계       X
# 디저트        갈기         2인분      매운맛없음        X
# 디저트        갈기         3인분      매운맛1단계       X
# 디저트        갈기         3인분      매운맛2단계       X
# 디저트        갈기         3인분      매운맛3단계       X
# 디저트        갈기         3인분      매운맛4단계       X
# 디저트        갈기         3인분      매운맛5단계       X
# 디저트        갈기         3인분      매운맛없음        X
# 디저트        갈기         4인분      매운맛1단계       X
# 디저트        갈기         4인분      매운맛2단계       X
# 디저트        갈기         4인분      매운맛3단계       X
# 디저트        갈기         4인분      매운맛4단계       X
# 디저트        갈기         4인분      매운맛5단계       X
# 디저트        갈기         4인분      매운맛없음        X
# 디저트        갈기         5인분      매운맛1단계       X
# 디저트        갈기         5인분      매운맛2단계       X
# 디저트        갈기         5인분      매운맛3단계       X
# 디저트        갈기         5인분      매운맛4단계       X
# 디저트        갈기         5인분      매운맛5단계       X
# 디저트        갈기         5인분      매운맛없음        X
# 디저트        갈기         nan      매운맛1단계       X
# 디저트        갈기         nan      매운맛2단계       X
# 디저트        갈기         nan      매운맛3단계       X
# 디저트        갈기         nan      매운맛4단계       X
# 디저트        갈기         nan      매운맛5단계       X
# 디저트        갈기         nan      매운맛없음        X
# 디저트        굽기         1인분      매운맛1단계       O
# 디저트        굽기         1인분      매운맛2단계       X
# 디저트        굽기         1인분      매운맛3단계       X
# 디저트        굽기         1인분      매운맛4단계       X
# 디저트        굽기         1인분      매운맛5단계       X
# 디저트        굽기         1인분      매운맛없음        O
# 디저트        굽기         2인분      매운맛1단계       O
# 디저트        굽기         2인분      매운맛2단계       X
# 디저트        굽기         2인분      매운맛3단계       X
# 디저트        굽기         2인분      매운맛4단계       X
# 디저트        굽기         2인분      매운맛5단계       X
# 디저트        굽기         2인분      매운맛없음        O
# 디저트        굽기         3인분      매운맛1단계       O
# 디저트        굽기         3인분      매운맛2단계       X
# 디저트        굽기         3인분      매운맛3단계       X
# 디저트        굽기         3인분      매운맛4단계       X
# 디저트        굽기         3인분      매운맛5단계       X
# 디저트        굽기         3인분      매운맛없음        O
# 디저트        굽기         4인분      매운맛1단계       O
# 디저트        굽기         4인분      매운맛2단계       X
# 디저트        굽기         4인분      매운맛3단계       X
# 디저트        굽기         4인분      매운맛4단계       X
# 디저트        굽기         4인분      매운맛5단계       X
# 디저트        굽기         4인분      매운맛없음        O
# 디저트        굽기         5인분      매운맛1단계       X
# 디저트        굽기         5인분      매운맛2단계       X
# 디저트        굽기         5인분      매운맛3단계       X
# 디저트        굽기         5인분      매운맛4단계       X
# 디저트        굽기         5인분      매운맛5단계       X
# 디저트        굽기         5인분      매운맛없음        O
# 디저트        굽기         nan      매운맛1단계       X
# 디저트        굽기         nan      매운맛2단계       X
# 디저트        굽기         nan      매운맛3단계       X
# 디저트        굽기         nan      매운맛4단계       X
# 디저트        굽기         nan      매운맛5단계       X
# 디저트        굽기         nan      매운맛없음        O
# 디저트        끓이기        1인분      매운맛1단계       O
# 디저트        끓이기        1인분      매운맛2단계       X
# 디저트        끓이기        1인분      매운맛3단계       X
# 디저트        끓이기        1인분      매운맛4단계       X
# 디저트        끓이기        1인분      매운맛5단계       X
# 디저트        끓이기        1인분      매운맛없음        O
# 디저트        끓이기        2인분      매운맛1단계       O
# 디저트        끓이기        2인분      매운맛2단계       X
# 디저트        끓이기        2인분      매운맛3단계       X
# 디저트        끓이기        2인분      매운맛4단계       X
# 디저트        끓이기        2인분      매운맛5단계       X
# 디저트        끓이기        2인분      매운맛없음        O
# 디저트        끓이기        3인분      매운맛1단계       X
# 디저트        끓이기        3인분      매운맛2단계       X
# 디저트        끓이기        3인분      매운맛3단계       X
# 디저트        끓이기        3인분      매운맛4단계       X
# 디저트        끓이기        3인분      매운맛5단계       X
# 디저트        끓이기        3인분      매운맛없음        O
# 디저트        끓이기        4인분      매운맛1단계       X
# 디저트        끓이기        4인분      매운맛2단계       X
# 디저트        끓이기        4인분      매운맛3단계       X
# 디저트        끓이기        4인분      매운맛4단계       X
# 디저트        끓이기        4인분      매운맛5단계       X
# 디저트        끓이기        4인분      매운맛없음        O
# 디저트        끓이기        5인분      매운맛1단계       X
# 디저트        끓이기        5인분      매운맛2단계       X
# 디저트        끓이기        5인분      매운맛3단계       X
# 디저트        끓이기        5인분      매운맛4단계       X
# 디저트        끓이기        5인분      매운맛5단계       X
# 디저트        끓이기        5인분      매운맛없음        O
# 디저트        끓이기        nan      매운맛1단계       X
# 디저트        끓이기        nan      매운맛2단계       X
# 디저트        끓이기        nan      매운맛3단계       X
# 디저트        끓이기        nan      매운맛4단계       X
# 디저트        끓이기        nan      매운맛5단계       X
# 디저트        끓이기        nan      매운맛없음        O
# 디저트        무침         1인분      매운맛1단계       X
# 디저트        무침         1인분      매운맛2단계       X
# 디저트        무침         1인분      매운맛3단계       X
# 디저트        무침         1인분      매운맛4단계       X
# 디저트        무침         1인분      매운맛5단계       X
# 디저트        무침         1인분      매운맛없음        O
# 디저트        무침         2인분      매운맛1단계       X
# 디저트        무침         2인분      매운맛2단계       X
# 디저트        무침         2인분      매운맛3단계       X
# 디저트        무침         2인분      매운맛4단계       X
# 디저트        무침         2인분      매운맛5단계       X
# 디저트        무침         2인분      매운맛없음        O
# 디저트        무침         3인분      매운맛1단계       X
# 디저트        무침         3인분      매운맛2단계       X
# 디저트        무침         3인분      매운맛3단계       X
# 디저트        무침         3인분      매운맛4단계       X
# 디저트        무침         3인분      매운맛5단계       X
# 디저트        무침         3인분      매운맛없음        O
# 디저트        무침         4인분      매운맛1단계       X
# 디저트        무침         4인분      매운맛2단계       X
# 디저트        무침         4인분      매운맛3단계       X
# 디저트        무침         4인분      매운맛4단계       X
# 디저트        무침         4인분      매운맛5단계       X
# 디저트        무침         4인분      매운맛없음        O
# 디저트        무침         5인분      매운맛1단계       X
# 디저트        무침         5인분      매운맛2단계       X
# 디저트        무침         5인분      매운맛3단계       X
# 디저트        무침         5인분      매운맛4단계       X
# 디저트        무침         5인분      매운맛5단계       X
# 디저트        무침         5인분      매운맛없음        X
# 디저트        무침         nan      매운맛1단계       X
# 디저트        무침         nan      매운맛2단계       X
# 디저트        무침         nan      매운맛3단계       X
# 디저트        무침         nan      매운맛4단계       X
# 디저트        무침         nan      매운맛5단계       X
# 디저트        무침         nan      매운맛없음        X
# 디저트        볶음         1인분      매운맛1단계       O
# 디저트        볶음         1인분      매운맛2단계       O
# 디저트        볶음         1인분      매운맛3단계       X
# 디저트        볶음         1인분      매운맛4단계       X
# 디저트        볶음         1인분      매운맛5단계       X
# 디저트        볶음         1인분      매운맛없음        O
# 디저트        볶음         2인분      매운맛1단계       O
# 디저트        볶음         2인분      매운맛2단계       X
# 디저트        볶음         2인분      매운맛3단계       X
# 디저트        볶음         2인분      매운맛4단계       X
# 디저트        볶음         2인분      매운맛5단계       X
# 디저트        볶음         2인분      매운맛없음        O
# 디저트        볶음         3인분      매운맛1단계       O
# 디저트        볶음         3인분      매운맛2단계       X
# 디저트        볶음         3인분      매운맛3단계       X
# 디저트        볶음         3인분      매운맛4단계       X
# 디저트        볶음         3인분      매운맛5단계       X
# 디저트        볶음         3인분      매운맛없음        X
# 디저트        볶음         4인분      매운맛1단계       X
# 디저트        볶음         4인분      매운맛2단계       X
# 디저트        볶음         4인분      매운맛3단계       X
# 디저트        볶음         4인분      매운맛4단계       X
# 디저트        볶음         4인분      매운맛5단계       X
# 디저트        볶음         4인분      매운맛없음        O
# 디저트        볶음         5인분      매운맛1단계       X
# 디저트        볶음         5인분      매운맛2단계       X
# 디저트        볶음         5인분      매운맛3단계       X
# 디저트        볶음         5인분      매운맛4단계       X
# 디저트        볶음         5인분      매운맛5단계       X
# 디저트        볶음         5인분      매운맛없음        X
# 디저트        볶음         nan      매운맛1단계       X
# 디저트        볶음         nan      매운맛2단계       X
# 디저트        볶음         nan      매운맛3단계       X
# 디저트        볶음         nan      매운맛4단계       X
# 디저트        볶음         nan      매운맛5단계       X
# 디저트        볶음         nan      매운맛없음        O
# 디저트        부침         1인분      매운맛1단계       O
# 디저트        부침         1인분      매운맛2단계       X
# 디저트        부침         1인분      매운맛3단계       X
# 디저트        부침         1인분      매운맛4단계       X
# 디저트        부침         1인분      매운맛5단계       X
# 디저트        부침         1인분      매운맛없음        O
# 디저트        부침         2인분      매운맛1단계       O
# 디저트        부침         2인분      매운맛2단계       X
# 디저트        부침         2인분      매운맛3단계       X
# 디저트        부침         2인분      매운맛4단계       X
# 디저트        부침         2인분      매운맛5단계       X
# 디저트        부침         2인분      매운맛없음        O
# 디저트        부침         3인분      매운맛1단계       O
# 디저트        부침         3인분      매운맛2단계       X
# 디저트        부침         3인분      매운맛3단계       X
# 디저트        부침         3인분      매운맛4단계       X
# 디저트        부침         3인분      매운맛5단계       X
# 디저트        부침         3인분      매운맛없음        O
# 디저트        부침         4인분      매운맛1단계       O
# 디저트        부침         4인분      매운맛2단계       X
# 디저트        부침         4인분      매운맛3단계       X
# 디저트        부침         4인분      매운맛4단계       X
# 디저트        부침         4인분      매운맛5단계       X
# 디저트        부침         4인분      매운맛없음        O
# 디저트        부침         5인분      매운맛1단계       X
# 디저트        부침         5인분      매운맛2단계       X
# 디저트        부침         5인분      매운맛3단계       X
# 디저트        부침         5인분      매운맛4단계       X
# 디저트        부침         5인분      매운맛5단계       X
# 디저트        부침         5인분      매운맛없음        X
# 디저트        부침         nan      매운맛1단계       O
# 디저트        부침         nan      매운맛2단계       X
# 디저트        부침         nan      매운맛3단계       X
# 디저트        부침         nan      매운맛4단계       X
# 디저트        부침         nan      매운맛5단계       X
# 디저트        부침         nan      매운맛없음        O
# 디저트        비빔         1인분      매운맛1단계       X
# 디저트        비빔         1인분      매운맛2단계       X
# 디저트        비빔         1인분      매운맛3단계       X
# 디저트        비빔         1인분      매운맛4단계       X
# 디저트        비빔         1인분      매운맛5단계       X
# 디저트        비빔         1인분      매운맛없음        O
# 디저트        비빔         2인분      매운맛1단계       X
# 디저트        비빔         2인분      매운맛2단계       X
# 디저트        비빔         2인분      매운맛3단계       X
# 디저트        비빔         2인분      매운맛4단계       X
# 디저트        비빔         2인분      매운맛5단계       X
# 디저트        비빔         2인분      매운맛없음        O
# 디저트        비빔         3인분      매운맛1단계       X
# 디저트        비빔         3인분      매운맛2단계       X
# 디저트        비빔         3인분      매운맛3단계       X
# 디저트        비빔         3인분      매운맛4단계       X
# 디저트        비빔         3인분      매운맛5단계       X
# 디저트        비빔         3인분      매운맛없음        X
# 디저트        비빔         4인분      매운맛1단계       X
# 디저트        비빔         4인분      매운맛2단계       X
# 디저트        비빔         4인분      매운맛3단계       X
# 디저트        비빔         4인분      매운맛4단계       X
# 디저트        비빔         4인분      매운맛5단계       X
# 디저트        비빔         4인분      매운맛없음        X
# 디저트        비빔         5인분      매운맛1단계       X
# 디저트        비빔         5인분      매운맛2단계       X
# 디저트        비빔         5인분      매운맛3단계       X
# 디저트        비빔         5인분      매운맛4단계       X
# 디저트        비빔         5인분      매운맛5단계       X
# 디저트        비빔         5인분      매운맛없음        X
# 디저트        비빔         nan      매운맛1단계       X
# 디저트        비빔         nan      매운맛2단계       X
# 디저트        비빔         nan      매운맛3단계       X
# 디저트        비빔         nan      매운맛4단계       X
# 디저트        비빔         nan      매운맛5단계       X
# 디저트        비빔         nan      매운맛없음        X
# 디저트        삶기         1인분      매운맛1단계       X
# 디저트        삶기         1인분      매운맛2단계       X
# 디저트        삶기         1인분      매운맛3단계       X
# 디저트        삶기         1인분      매운맛4단계       X
# 디저트        삶기         1인분      매운맛5단계       X
# 디저트        삶기         1인분      매운맛없음        O
# 디저트        삶기         2인분      매운맛1단계       X
# 디저트        삶기         2인분      매운맛2단계       X
# 디저트        삶기         2인분      매운맛3단계       X
# 디저트        삶기         2인분      매운맛4단계       X
# 디저트        삶기         2인분      매운맛5단계       X
# 디저트        삶기         2인분      매운맛없음        O
# 디저트        삶기         3인분      매운맛1단계       O
# 디저트        삶기         3인분      매운맛2단계       X
# 디저트        삶기         3인분      매운맛3단계       X
# 디저트        삶기         3인분      매운맛4단계       X
# 디저트        삶기         3인분      매운맛5단계       X
# 디저트        삶기         3인분      매운맛없음        O
# 디저트        삶기         4인분      매운맛1단계       X
# 디저트        삶기         4인분      매운맛2단계       X
# 디저트        삶기         4인분      매운맛3단계       X
# 디저트        삶기         4인분      매운맛4단계       X
# 디저트        삶기         4인분      매운맛5단계       X
# 디저트        삶기         4인분      매운맛없음        O
# 디저트        삶기         5인분      매운맛1단계       X
# 디저트        삶기         5인분      매운맛2단계       X
# 디저트        삶기         5인분      매운맛3단계       X
# 디저트        삶기         5인분      매운맛4단계       X
# 디저트        삶기         5인분      매운맛5단계       X
# 디저트        삶기         5인분      매운맛없음        O
# 디저트        삶기         nan      매운맛1단계       X
# 디저트        삶기         nan      매운맛2단계       X
# 디저트        삶기         nan      매운맛3단계       X
# 디저트        삶기         nan      매운맛4단계       X
# 디저트        삶기         nan      매운맛5단계       X
# 디저트        삶기         nan      매운맛없음        O
# 디저트        절임         1인분      매운맛1단계       X
# 디저트        절임         1인분      매운맛2단계       X
# 디저트        절임         1인분      매운맛3단계       X
# 디저트        절임         1인분      매운맛4단계       X
# 디저트        절임         1인분      매운맛5단계       X
# 디저트        절임         1인분      매운맛없음        O
# 디저트        절임         2인분      매운맛1단계       X
# 디저트        절임         2인분      매운맛2단계       X
# 디저트        절임         2인분      매운맛3단계       X
# 디저트        절임         2인분      매운맛4단계       X
# 디저트        절임         2인분      매운맛5단계       X
# 디저트        절임         2인분      매운맛없음        O
# 디저트        절임         3인분      매운맛1단계       X
# 디저트        절임         3인분      매운맛2단계       X
# 디저트        절임         3인분      매운맛3단계       X
# 디저트        절임         3인분      매운맛4단계       X
# 디저트        절임         3인분      매운맛5단계       X
# 디저트        절임         3인분      매운맛없음        X
# 디저트        절임         4인분      매운맛1단계       X
# 디저트        절임         4인분      매운맛2단계       X
# 디저트        절임         4인분      매운맛3단계       X
# 디저트        절임         4인분      매운맛4단계       X
# 디저트        절임         4인분      매운맛5단계       X
# 디저트        절임         4인분      매운맛없음        O
# 디저트        절임         5인분      매운맛1단계       X
# 디저트        절임         5인분      매운맛2단계       X
# 디저트        절임         5인분      매운맛3단계       X
# 디저트        절임         5인분      매운맛4단계       X
# 디저트        절임         5인분      매운맛5단계       X
# 디저트        절임         5인분      매운맛없음        X
# 디저트        절임         nan      매운맛1단계       X
# 디저트        절임         nan      매운맛2단계       X
# 디저트        절임         nan      매운맛3단계       X
# 디저트        절임         nan      매운맛4단계       X
# 디저트        절임         nan      매운맛5단계       X
# 디저트        절임         nan      매운맛없음        X
# 디저트        조림         1인분      매운맛1단계       X
# 디저트        조림         1인분      매운맛2단계       X
# 디저트        조림         1인분      매운맛3단계       X
# 디저트        조림         1인분      매운맛4단계       X
# 디저트        조림         1인분      매운맛5단계       X
# 디저트        조림         1인분      매운맛없음        O
# 디저트        조림         2인분      매운맛1단계       O
# 디저트        조림         2인분      매운맛2단계       X
# 디저트        조림         2인분      매운맛3단계       X
# 디저트        조림         2인분      매운맛4단계       X
# 디저트        조림         2인분      매운맛5단계       X
# 디저트        조림         2인분      매운맛없음        O
# 디저트        조림         3인분      매운맛1단계       X
# 디저트        조림         3인분      매운맛2단계       X
# 디저트        조림         3인분      매운맛3단계       X
# 디저트        조림         3인분      매운맛4단계       X
# 디저트        조림         3인분      매운맛5단계       X
# 디저트        조림         3인분      매운맛없음        X
# 디저트        조림         4인분      매운맛1단계       X
# 디저트        조림         4인분      매운맛2단계       X
# 디저트        조림         4인분      매운맛3단계       X
# 디저트        조림         4인분      매운맛4단계       X
# 디저트        조림         4인분      매운맛5단계       X
# 디저트        조림         4인분      매운맛없음        O
# 디저트        조림         5인분      매운맛1단계       X
# 디저트        조림         5인분      매운맛2단계       X
# 디저트        조림         5인분      매운맛3단계       X
# 디저트        조림         5인분      매운맛4단계       X
# 디저트        조림         5인분      매운맛5단계       X
# 디저트        조림         5인분      매운맛없음        X
# 디저트        조림         nan      매운맛1단계       X
# 디저트        조림         nan      매운맛2단계       X
# 디저트        조림         nan      매운맛3단계       X
# 디저트        조림         nan      매운맛4단계       X
# 디저트        조림         nan      매운맛5단계       X
# 디저트        조림         nan      매운맛없음        O
# 디저트        찜          1인분      매운맛1단계       X
# 디저트        찜          1인분      매운맛2단계       X
# 디저트        찜          1인분      매운맛3단계       X
# 디저트        찜          1인분      매운맛4단계       X
# 디저트        찜          1인분      매운맛5단계       X
# 디저트        찜          1인분      매운맛없음        O
# 디저트        찜          2인분      매운맛1단계       X
# 디저트        찜          2인분      매운맛2단계       X
# 디저트        찜          2인분      매운맛3단계       X
# 디저트        찜          2인분      매운맛4단계       X
# 디저트        찜          2인분      매운맛5단계       X
# 디저트        찜          2인분      매운맛없음        O
# 디저트        찜          3인분      매운맛1단계       X
# 디저트        찜          3인분      매운맛2단계       X
# 디저트        찜          3인분      매운맛3단계       X
# 디저트        찜          3인분      매운맛4단계       X
# 디저트        찜          3인분      매운맛5단계       X
# 디저트        찜          3인분      매운맛없음        O
# 디저트        찜          4인분      매운맛1단계       X
# 디저트        찜          4인분      매운맛2단계       X
# 디저트        찜          4인분      매운맛3단계       X
# 디저트        찜          4인분      매운맛4단계       X
# 디저트        찜          4인분      매운맛5단계       X
# 디저트        찜          4인분      매운맛없음        O
# 디저트        찜          5인분      매운맛1단계       X
# 디저트        찜          5인분      매운맛2단계       X
# 디저트        찜          5인분      매운맛3단계       X
# 디저트        찜          5인분      매운맛4단계       X
# 디저트        찜          5인분      매운맛5단계       X
# 디저트        찜          5인분      매운맛없음        O
# 디저트        찜          nan      매운맛1단계       X
# 디저트        찜          nan      매운맛2단계       X
# 디저트        찜          nan      매운맛3단계       X
# 디저트        찜          nan      매운맛4단계       X
# 디저트        찜          nan      매운맛5단계       X
# 디저트        찜          nan      매운맛없음        O
# 디저트        튀김         1인분      매운맛1단계       O
# 디저트        튀김         1인분      매운맛2단계       X
# 디저트        튀김         1인분      매운맛3단계       X
# 디저트        튀김         1인분      매운맛4단계       X
# 디저트        튀김         1인분      매운맛5단계       X
# 디저트        튀김         1인분      매운맛없음        O
# ...
# 퓨전         부침         1인분      매운맛1단계       O
# 퓨전         부침         1인분      매운맛2단계       X
# 퓨전         부침         1인분      매운맛3단계       X
# 퓨전         부침         1인분      매운맛4단계       X
# 퓨전         부침         1인분      매운맛5단계       X
# 퓨전         부침         1인분      매운맛없음        O
# 퓨전         부침         2인분      매운맛1단계       O
# 퓨전         부침         2인분      매운맛2단계       X
# 퓨전         부침         2인분      매운맛3단계       X
# 퓨전         부침         2인분      매운맛4단계       O
# 퓨전         부침         2인분      매운맛5단계       X
# 퓨전         부침         2인분      매운맛없음        O
# 퓨전         부침         3인분      매운맛1단계       O
# 퓨전         부침         3인분      매운맛2단계       X
# 퓨전         부침         3인분      매운맛3단계       X
# 퓨전         부침         3인분      매운맛4단계       X
# 퓨전         부침         3인분      매운맛5단계       X
# 퓨전         부침         3인분      매운맛없음        O
# 퓨전         부침         4인분      매운맛1단계       O
# 퓨전         부침         4인분      매운맛2단계       X
# 퓨전         부침         4인분      매운맛3단계       X
# 퓨전         부침         4인분      매운맛4단계       X
# 퓨전         부침         4인분      매운맛5단계       X
# 퓨전         부침         4인분      매운맛없음        O
# 퓨전         부침         5인분      매운맛1단계       X
# 퓨전         부침         5인분      매운맛2단계       X
# 퓨전         부침         5인분      매운맛3단계       X
# 퓨전         부침         5인분      매운맛4단계       X
# 퓨전         부침         5인분      매운맛5단계       X
# 퓨전         부침         5인분      매운맛없음        O
# 퓨전         부침         nan      매운맛1단계       X
# 퓨전         부침         nan      매운맛2단계       X
# 퓨전         부침         nan      매운맛3단계       X
# 퓨전         부침         nan      매운맛4단계       X
# 퓨전         부침         nan      매운맛5단계       X
# 퓨전         부침         nan      매운맛없음        O
# 퓨전         비빔         1인분      매운맛1단계       X
# 퓨전         비빔         1인분      매운맛2단계       X
# 퓨전         비빔         1인분      매운맛3단계       X
# 퓨전         비빔         1인분      매운맛4단계       X
# 퓨전         비빔         1인분      매운맛5단계       X
# 퓨전         비빔         1인분      매운맛없음        O
# 퓨전         비빔         2인분      매운맛1단계       X
# 퓨전         비빔         2인분      매운맛2단계       X
# 퓨전         비빔         2인분      매운맛3단계       X
# 퓨전         비빔         2인분      매운맛4단계       X
# 퓨전         비빔         2인분      매운맛5단계       X
# 퓨전         비빔         2인분      매운맛없음        O
# 퓨전         비빔         3인분      매운맛1단계       O
# 퓨전         비빔         3인분      매운맛2단계       X
# 퓨전         비빔         3인분      매운맛3단계       X
# 퓨전         비빔         3인분      매운맛4단계       X
# 퓨전         비빔         3인분      매운맛5단계       X
# 퓨전         비빔         3인분      매운맛없음        X
# 퓨전         비빔         4인분      매운맛1단계       X
# 퓨전         비빔         4인분      매운맛2단계       X
# 퓨전         비빔         4인분      매운맛3단계       X
# 퓨전         비빔         4인분      매운맛4단계       X
# 퓨전         비빔         4인분      매운맛5단계       X
# 퓨전         비빔         4인분      매운맛없음        X
# 퓨전         비빔         5인분      매운맛1단계       X
# 퓨전         비빔         5인분      매운맛2단계       X
# 퓨전         비빔         5인분      매운맛3단계       X
# 퓨전         비빔         5인분      매운맛4단계       X
# 퓨전         비빔         5인분      매운맛5단계       X
# 퓨전         비빔         5인분      매운맛없음        X
# 퓨전         비빔         nan      매운맛1단계       X
# 퓨전         비빔         nan      매운맛2단계       X
# 퓨전         비빔         nan      매운맛3단계       X
# 퓨전         비빔         nan      매운맛4단계       X
# 퓨전         비빔         nan      매운맛5단계       X
# 퓨전         비빔         nan      매운맛없음        X
# 퓨전         삶기         1인분      매운맛1단계       X
# 퓨전         삶기         1인분      매운맛2단계       X
# 퓨전         삶기         1인분      매운맛3단계       X
# 퓨전         삶기         1인분      매운맛4단계       X
# 퓨전         삶기         1인분      매운맛5단계       X
# 퓨전         삶기         1인분      매운맛없음        O
# 퓨전         삶기         2인분      매운맛1단계       X
# 퓨전         삶기         2인분      매운맛2단계       O
# 퓨전         삶기         2인분      매운맛3단계       X
# 퓨전         삶기         2인분      매운맛4단계       X
# 퓨전         삶기         2인분      매운맛5단계       X
# 퓨전         삶기         2인분      매운맛없음        O
# 퓨전         삶기         3인분      매운맛1단계       X
# 퓨전         삶기         3인분      매운맛2단계       X
# 퓨전         삶기         3인분      매운맛3단계       X
# 퓨전         삶기         3인분      매운맛4단계       X
# 퓨전         삶기         3인분      매운맛5단계       X
# 퓨전         삶기         3인분      매운맛없음        O
# 퓨전         삶기         4인분      매운맛1단계       X
# 퓨전         삶기         4인분      매운맛2단계       X
# 퓨전         삶기         4인분      매운맛3단계       X
# 퓨전         삶기         4인분      매운맛4단계       X
# 퓨전         삶기         4인분      매운맛5단계       X
# 퓨전         삶기         4인분      매운맛없음        O
# 퓨전         삶기         5인분      매운맛1단계       X
# 퓨전         삶기         5인분      매운맛2단계       X
# 퓨전         삶기         5인분      매운맛3단계       X
# 퓨전         삶기         5인분      매운맛4단계       X
# 퓨전         삶기         5인분      매운맛5단계       X
# 퓨전         삶기         5인분      매운맛없음        X
# 퓨전         삶기         nan      매운맛1단계       X
# 퓨전         삶기         nan      매운맛2단계       X
# 퓨전         삶기         nan      매운맛3단계       X
# 퓨전         삶기         nan      매운맛4단계       X
# 퓨전         삶기         nan      매운맛5단계       X
# 퓨전         삶기         nan      매운맛없음        X
# 퓨전         절임         1인분      매운맛1단계       O
# 퓨전         절임         1인분      매운맛2단계       X
# 퓨전         절임         1인분      매운맛3단계       X
# 퓨전         절임         1인분      매운맛4단계       X
# 퓨전         절임         1인분      매운맛5단계       X
# 퓨전         절임         1인분      매운맛없음        X
# 퓨전         절임         2인분      매운맛1단계       X
# 퓨전         절임         2인분      매운맛2단계       X
# 퓨전         절임         2인분      매운맛3단계       X
# 퓨전         절임         2인분      매운맛4단계       X
# 퓨전         절임         2인분      매운맛5단계       X
# 퓨전         절임         2인분      매운맛없음        O
# 퓨전         절임         3인분      매운맛1단계       X
# 퓨전         절임         3인분      매운맛2단계       X
# 퓨전         절임         3인분      매운맛3단계       X
# 퓨전         절임         3인분      매운맛4단계       X
# 퓨전         절임         3인분      매운맛5단계       X
# 퓨전         절임         3인분      매운맛없음        X
# 퓨전         절임         4인분      매운맛1단계       X
# 퓨전         절임         4인분      매운맛2단계       X
# 퓨전         절임         4인분      매운맛3단계       X
# 퓨전         절임         4인분      매운맛4단계       X
# 퓨전         절임         4인분      매운맛5단계       X
# 퓨전         절임         4인분      매운맛없음        O
# 퓨전         절임         5인분      매운맛1단계       X
# 퓨전         절임         5인분      매운맛2단계       X
# 퓨전         절임         5인분      매운맛3단계       X
# 퓨전         절임         5인분      매운맛4단계       X
# 퓨전         절임         5인분      매운맛5단계       X
# 퓨전         절임         5인분      매운맛없음        X
# 퓨전         절임         nan      매운맛1단계       X
# 퓨전         절임         nan      매운맛2단계       X
# 퓨전         절임         nan      매운맛3단계       X
# 퓨전         절임         nan      매운맛4단계       X
# 퓨전         절임         nan      매운맛5단계       X
# 퓨전         절임         nan      매운맛없음        X
# 퓨전         조림         1인분      매운맛1단계       O
# 퓨전         조림         1인분      매운맛2단계       X
# 퓨전         조림         1인분      매운맛3단계       X
# 퓨전         조림         1인분      매운맛4단계       X
# 퓨전         조림         1인분      매운맛5단계       X
# 퓨전         조림         1인분      매운맛없음        O
# 퓨전         조림         2인분      매운맛1단계       X
# 퓨전         조림         2인분      매운맛2단계       X
# 퓨전         조림         2인분      매운맛3단계       X
# 퓨전         조림         2인분      매운맛4단계       X
# 퓨전         조림         2인분      매운맛5단계       X
# 퓨전         조림         2인분      매운맛없음        O
# 퓨전         조림         3인분      매운맛1단계       X
# 퓨전         조림         3인분      매운맛2단계       X
# 퓨전         조림         3인분      매운맛3단계       X
# 퓨전         조림         3인분      매운맛4단계       X
# 퓨전         조림         3인분      매운맛5단계       X
# 퓨전         조림         3인분      매운맛없음        O
# 퓨전         조림         4인분      매운맛1단계       O
# 퓨전         조림         4인분      매운맛2단계       X
# 퓨전         조림         4인분      매운맛3단계       X
# 퓨전         조림         4인분      매운맛4단계       O
# 퓨전         조림         4인분      매운맛5단계       X
# 퓨전         조림         4인분      매운맛없음        O
# 퓨전         조림         5인분      매운맛1단계       X
# 퓨전         조림         5인분      매운맛2단계       X
# 퓨전         조림         5인분      매운맛3단계       X
# 퓨전         조림         5인분      매운맛4단계       X
# 퓨전         조림         5인분      매운맛5단계       X
# 퓨전         조림         5인분      매운맛없음        X
# 퓨전         조림         nan      매운맛1단계       X
# 퓨전         조림         nan      매운맛2단계       X
# 퓨전         조림         nan      매운맛3단계       X
# 퓨전         조림         nan      매운맛4단계       X
# 퓨전         조림         nan      매운맛5단계       X
# 퓨전         조림         nan      매운맛없음        X
# 퓨전         찜          1인분      매운맛1단계       O
# 퓨전         찜          1인분      매운맛2단계       X
# 퓨전         찜          1인분      매운맛3단계       X
# 퓨전         찜          1인분      매운맛4단계       X
# 퓨전         찜          1인분      매운맛5단계       X
# 퓨전         찜          1인분      매운맛없음        O
# 퓨전         찜          2인분      매운맛1단계       O
# 퓨전         찜          2인분      매운맛2단계       X
# 퓨전         찜          2인분      매운맛3단계       X
# 퓨전         찜          2인분      매운맛4단계       X
# 퓨전         찜          2인분      매운맛5단계       X
# 퓨전         찜          2인분      매운맛없음        O
# 퓨전         찜          3인분      매운맛1단계       O
# 퓨전         찜          3인분      매운맛2단계       O
# 퓨전         찜          3인분      매운맛3단계       X
# 퓨전         찜          3인분      매운맛4단계       X
# 퓨전         찜          3인분      매운맛5단계       X
# 퓨전         찜          3인분      매운맛없음        O
# 퓨전         찜          4인분      매운맛1단계       X
# 퓨전         찜          4인분      매운맛2단계       X
# 퓨전         찜          4인분      매운맛3단계       X
# 퓨전         찜          4인분      매운맛4단계       X
# 퓨전         찜          4인분      매운맛5단계       X
# 퓨전         찜          4인분      매운맛없음        O
# 퓨전         찜          5인분      매운맛1단계       X
# 퓨전         찜          5인분      매운맛2단계       X
# 퓨전         찜          5인분      매운맛3단계       X
# 퓨전         찜          5인분      매운맛4단계       X
# 퓨전         찜          5인분      매운맛5단계       X
# 퓨전         찜          5인분      매운맛없음        O
# 퓨전         찜          nan      매운맛1단계       X
# 퓨전         찜          nan      매운맛2단계       X
# 퓨전         찜          nan      매운맛3단계       X
# 퓨전         찜          nan      매운맛4단계       X
# 퓨전         찜          nan      매운맛5단계       X
# 퓨전         찜          nan      매운맛없음        X
# 퓨전         튀김         1인분      매운맛1단계       O
# 퓨전         튀김         1인분      매운맛2단계       X
# 퓨전         튀김         1인분      매운맛3단계       O
# 퓨전         튀김         1인분      매운맛4단계       X
# 퓨전         튀김         1인분      매운맛5단계       X
# 퓨전         튀김         1인분      매운맛없음        O
# 퓨전         튀김         2인분      매운맛1단계       O
# 퓨전         튀김         2인분      매운맛2단계       O
# 퓨전         튀김         2인분      매운맛3단계       X
# 퓨전         튀김         2인분      매운맛4단계       X
# 퓨전         튀김         2인분      매운맛5단계       X
# 퓨전         튀김         2인분      매운맛없음        O
# 퓨전         튀김         3인분      매운맛1단계       O
# 퓨전         튀김         3인분      매운맛2단계       X
# 퓨전         튀김         3인분      매운맛3단계       X
# 퓨전         튀김         3인분      매운맛4단계       X
# 퓨전         튀김         3인분      매운맛5단계       X
# 퓨전         튀김         3인분      매운맛없음        O
# 퓨전         튀김         4인분      매운맛1단계       O
# 퓨전         튀김         4인분      매운맛2단계       X
# 퓨전         튀김         4인분      매운맛3단계       X
# 퓨전         튀김         4인분      매운맛4단계       X
# 퓨전         튀김         4인분      매운맛5단계       X
# 퓨전         튀김         4인분      매운맛없음        O
# 퓨전         튀김         5인분      매운맛1단계       X
# 퓨전         튀김         5인분      매운맛2단계       X
# 퓨전         튀김         5인분      매운맛3단계       X
# 퓨전         튀김         5인분      매운맛4단계       X
# 퓨전         튀김         5인분      매운맛5단계       X
# 퓨전         튀김         5인분      매운맛없음        X
# 퓨전         튀김         nan      매운맛1단계       X
# 퓨전         튀김         nan      매운맛2단계       X
# 퓨전         튀김         nan      매운맛3단계       X
# 퓨전         튀김         nan      매운맛4단계       X
# 퓨전         튀김         nan      매운맛5단계       X
# 퓨전         튀김         nan      매운맛없음        O
# 퓨전         회          1인분      매운맛1단계       O
# 퓨전         회          1인분      매운맛2단계       X
# 퓨전         회          1인분      매운맛3단계       X
# 퓨전         회          1인분      매운맛4단계       X
# 퓨전         회          1인분      매운맛5단계       X
# 퓨전         회          1인분      매운맛없음        O
# 퓨전         회          2인분      매운맛1단계       X
# 퓨전         회          2인분      매운맛2단계       X
# 퓨전         회          2인분      매운맛3단계       X
# 퓨전         회          2인분      매운맛4단계       X
# 퓨전         회          2인분      매운맛5단계       X
# 퓨전         회          2인분      매운맛없음        X
# 퓨전         회          3인분      매운맛1단계       X
# 퓨전         회          3인분      매운맛2단계       X
# 퓨전         회          3인분      매운맛3단계       X
# 퓨전         회          3인분      매운맛4단계       X
# 퓨전         회          3인분      매운맛5단계       X
# 퓨전         회          3인분      매운맛없음        X
# 퓨전         회          4인분      매운맛1단계       X
# 퓨전         회          4인분      매운맛2단계       X
# 퓨전         회          4인분      매운맛3단계       X
# 퓨전         회          4인분      매운맛4단계       X
# 퓨전         회          4인분      매운맛5단계       X
# 퓨전         회          4인분      매운맛없음        X
# 퓨전         회          5인분      매운맛1단계       X
# 퓨전         회          5인분      매운맛2단계       X
# 퓨전         회          5인분      매운맛3단계       X
# 퓨전         회          5인분      매운맛4단계       X
# 퓨전         회          5인분      매운맛5단계       X
# 퓨전         회          5인분      매운맛없음        X
# 퓨전         회          nan      매운맛1단계       X
# 퓨전         회          nan      매운맛2단계       X
# 퓨전         회          nan      매운맛3단계       X
# 퓨전         회          nan      매운맛4단계       X
# 퓨전         회          nan      매운맛5단계       X
# 퓨전         회          nan      매운맛없음        X
#
# 통계:
# 전체 가능한 조합 수: 5616
# 실제 존재하는 조합 수: 987
# 비율: 17.57%
#
# 각 카테고리별 unique 값의 수:
# type_key: 12 개
# method_key: 13 개
# servings: 6 개
# spicy_level: 6 개

# %%
# 몇개의 dataset을 뽑는 것이 좋을지 확인
def analyze_and_create_test_set(df, n_samples=10):
    """
    데이터셋의 실제 조합을 분석하고, 균형잡힌 테스트셋을 생성합니다.
    """
    # 데이터 복사 및 전처리
    df_copy = df.copy()
    df_copy['servings'] = df_copy['servings'].astype(str)
    
    # 1. 실제 존재하는 조합 분석
    actual_combinations = df_copy.groupby(
        ['type_key', 'method_key', 'servings', 'spicy_level']
    ).size().reset_index(name='count')
    
    print(f"실제 존재하는 unique 조합의 수: {len(actual_combinations)}")
    
    # 2. 조합별 샘플 수 계산
    if n_samples < len(actual_combinations):
        print(f"\n경고: 요청한 샘플 수({n_samples})가 실제 조합의 수({len(actual_combinations)})보다 작습니다.")
        print("각 조합을 최소한 한 번씩 포함하려면 더 큰 n_samples가 필요합니다.")
    
    # 3. 조합별 분포 확인
    print("\n조합별 샘플 수 분포:")
    print(actual_combinations['count'].describe())
    
    # 4. 희소한 조합과 빈번한 조합 확인
    print("\n가장 희소한 조합 (상위 5개):")
    print(actual_combinations.nsmallest(5, 'count')[
        ['type_key', 'method_key', 'servings', 'spicy_level', 'count']
    ])
    
    print("\n가장 빈번한 조합 (상위 5개):")
    print(actual_combinations.nlargest(5, 'count')[
        ['type_key', 'method_key', 'servings', 'spicy_level', 'count']
    ])
    
    # 5. 각 카테고리별 분포
    print("\n각 카테고리별 분포:")
    for col in ['type_key', 'method_key', 'servings', 'spicy_level']:
        print(f"\n{col} 분포:")
        print(df_copy[col].value_counts())
    
    # 6. 샘플링 전략 제안
    recommended_samples = min(len(actual_combinations), max(n_samples, 1000))
    print(f"\n권장 샘플 수: {recommended_samples}")
    print(f"이유: 실제 존재하는 {len(actual_combinations)}개의 조합 중 의미있는 샘플을 추출하기 위해")
    
    return {
        'total_combinations': len(actual_combinations),
        'combination_stats': actual_combinations['count'].describe(),
        'actual_combinations': actual_combinations
    }

# 함수 실행
analysis_results = analyze_and_create_test_set(df, n_samples=10)
# Out:
# 실제 존재하는 unique 조합의 수: 987
#
# 경고: 요청한 샘플 수(10)가 실제 조합의 수(987)보다 작습니다.
# 각 조합을 최소한 한 번씩 포함하려면 더 큰 n_samples가 필요합니다.
#
# 조합별 샘플 수 분포:
# count    987.000000
# mean      18.022290
# std       46.524978
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       12.000000
# max      629.000000
# Name: count, dtype: float64
#
# 가장 희소한 조합 (상위 5개):
#    type_key method_key servings spicy_level  count
# 0      국/찌개         갈기      1인분       매운맛없음      1
# 1      국/찌개         굽기      3인분       매운맛없음      1
# 4      국/찌개        끓이기      1인분      매운맛3단계      1
# 23     국/찌개        끓이기      nan      매운맛2단계      1
# 24     국/찌개        끓이기      nan      매운맛3단계      1
#
# 가장 빈번한 조합 (상위 5개):
#     type_key method_key servings spicy_level  count
# 296       반찬         부침      2인분       매운맛없음    629
# 277       반찬         볶음      2인분       매운맛없음    450
# 361       반찬         조림      4인분       매운맛없음    355
# 285       반찬         볶음      4인분       매운맛없음    348
# 371       반찬          찜      2인분       매운맛없음    303
#
# 각 카테고리별 분포:
#
# type_key 분포:
# type_key
# 반찬         9064
# 밥/죽/떡       887
# 국/찌개        877
# 양식          845
# 면/만두        842
# 빵/과자        835
# 샐러드         830
# 디저트         812
# 스프          781
# 퓨전          776
# 양념/잼/소스     771
# 차/음료/술      468
# Name: count, dtype: int64
#
# method_key 분포:
# method_key
# 끓이기    3463
# 볶음     3015
# 굽기     2715
# 부침     1851
# 무침     1830
# 조림     1728
# 찜      1179
# 튀김      754
# 절임      516
# 비빔      397
# 삶기      276
# 회        43
# 갈기       21
# Name: count, dtype: int64
#
# servings 분포:
# servings
# 2인분    6784
# 4인분    4039
# 1인분    3355
# 3인분    2492
# nan     675
# 5인분     443
# Name: count, dtype: int64
#
# spicy_level 분포:
# spicy_level
# 매운맛없음     12820
# 매운맛1단계     4504
# 매운맛2단계      370
# 매운맛3단계       63
# 매운맛4단계       27
# 매운맛5단계        4
# Name: count, dtype: int64
#
# 권장 샘플 수: 987
# 이유: 실제 존재하는 987개의 조합 중 의미있는 샘플을 추출하기 위해

# %%
# def create_balanced_test_set(df, n_samples=10, random_state=42):
#     """
#     균형 잡힌 테스트 셋을 생성하는 함수
#     """
#     np.random.seed(random_state)
    
#     # 데이터 복사 및 전처리
#     df_copy = df.copy()
#     df_copy['servings'] = df_copy['servings'].astype(str)
    
#     # 1. 실제 존재하는 조합 확인
#     existing_combinations = df_copy.groupby(
#         ['type_key', 'method_key', 'servings', 'spicy_level']
#     ).size().reset_index(name='count')
    
#     # 2. n_samples 검증
#     if n_samples > len(existing_combinations):
#         print(f"Warning: n_samples({n_samples})가 실제 존재하는 조합의 수({len(existing_combinations)})보다 큽니다.")
#         n_samples = len(existing_combinations)
    
#     # 3. 희소한 조합부터 선택
#     existing_combinations = existing_combinations.sort_values('count')
#     selected_combinations = existing_combinations.head(n_samples)
    
#     # 4. 선택된 조합에서 샘플 추출
#     selected_samples = []
#     for _, row in selected_combinations.iterrows():
#         mask = (df_copy['type_key'] == row['type_key']) & \
#                (df_copy['method_key'] == row['method_key']) & \
#                (df_copy['servings'] == row['servings']) & \
#                (df_copy['spicy_level'] == row['spicy_level'])
        
#         samples = df_copy[mask]
#         if len(samples) > 0:
#             selected_sample = samples.sample(n=1, random_state=random_state)
#             selected_samples.append(selected_sample)
    
#     # 5. 최종 테스트 셋 생성
#     test_set = pd.concat(selected_samples)
    
#     # 6. 분포 검증
#     print("\n최종 테스트 셋 조합 수:", len(test_set))
#     print("\n선택된 조합들:")
#     for _, row in test_set.iterrows():
#         print(f"type: {row['type_key']}, method: {row['method_key']}, "
#               f"servings: {row['servings']}, spicy: {row['spicy_level']}")
    
#     return test_set

# # 함수 실행
# test_set = create_balanced_test_set(df, n_samples=10)
# Out:
# 최종 테스트 셋 조합 수: 10
#
# 선택된 조합들:
# type: 국/찌개, method: 갈기, servings: 1인분, spicy: 매운맛없음
# type: 빵/과자, method: 튀김, servings: 1인분, spicy: 매운맛4단계
# type: 빵/과자, method: 찜, servings: 5인분, spicy: 매운맛없음
# type: 빵/과자, method: 찜, servings: 3인분, spicy: 매운맛없음
# type: 빵/과자, method: 찜, servings: 3인분, spicy: 매운맛1단계
# type: 빵/과자, method: 절임, servings: 3인분, spicy: 매운맛없음
# type: 빵/과자, method: 절임, servings: 2인분, spicy: 매운맛없음
# type: 빵/과자, method: 삶기, servings: 5인분, spicy: 매운맛없음
# type: 빵/과자, method: 삶기, servings: 4인분, spicy: 매운맛1단계
# type: 빵/과자, method: 비빔, servings: 4인분, spicy: 매운맛없음

# %%
# test_set.describe()
# Out:
#                              _id    title type_key method_key servings  \
# count                         10       10       10         10       10
# unique                        10       10        2          6        5
# top     67610699846f9e5eb975e6fe  도토리묵 콩국     빵/과자          찜      3인분
# freq                           1        1        9          3        3
#
#        cooking_time difficulty  \
# count             9          9
# unique            5          2
# top          60분 이내         초급
# freq              3          8
#
#                                               ingredients  \
# count                                                  10
# unique                                                 10
# top     ['곤약 10g', '서리태 20g', '마늘 2g', '마늘쫑 5g', '파프리카...
# freq                                                    1
#
#                                             cooking_steps tips  \
# count                                                  10   10
# unique                                                 10    4
# top     ['1. 대두는 6시간 이상 물에 불린다.', '2. 불린통은 20~25분 정도 삶...   []
# freq                                                    1    7
#
#                                      recipe_type spicy_level
# count                                         10          10
# unique                                        10           3
# top     ['건강식', '고단백', '한식', '저칼로리', '채식', '스프']       매운맛없음
# freq                                           1           7

# %% [markdown]
# ## 4. 데이터셋 저장

# %%
# CSV 파일로 저장
output_file = 'data/diverse_recipes_dataset.csv'
df_sample.to_csv(output_file, index=False)
print(f"다양한 레시피 데이터셋이 {output_file}에 저장되었습니다.")

# 저장된 데이터 확인
df_sample.describe()
# Out:
# 다양한 레시피 데이터셋이 data/diverse_recipes_dataset.csv에 저장되었습니다.
#                              _id  title type_key method_key servings  \
# count                         35     35       35         35       34
# unique                        35     35       12         13        5
# top     67610699846f9e5eb975e532  연어샐러드       반찬        끓이기      1인분
# freq                           1      1       10         10       12
#
#        cooking_time difficulty  \
# count            33         33
# unique            7          2
# top          30분 이내         초급
# freq             14         29
#
#                                               ingredients  \
# count                                                  35
# unique                                                 35
# top     ['연어(150g)', '레몬(1/4개)', '발사믹식초(50g)', '어린잎채소(...
# freq                                                    1
#
#                                             cooking_steps tips  \
# count                                                  35   35
# unique                                                 35   17
# top     ['1. 연어는 깍둑썰기한다.', '2. 썰어 놓은 연어는 후춧가루와 레몬으로 마리...   []
# freq                                                    1   19
#
#                           recipe_type spicy_level
# count                              35          35
# unique                             35           6
# top     ['고단백', '저칼로리', '해산물', '샐러드']       매운맛없음
# freq                                1          23

# %% [markdown]
# ## 6. 분포 시각화 (선택사항)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.rcParams['font.family'] = 'AppleGothic'  # Mac의 경우

# 각 컬럼에 대해 값을 집계하고 정렬
servings_order = df_sample['servings'].value_counts().sort_values(ascending=False).index
method_key_order = df_sample['method_key'].value_counts().sort_values(ascending=False).index
type_key_order = df_sample['type_key'].value_counts().sort_values(ascending=False).index
spicy_level_order = df_sample['spicy_level'].value_counts().sort_values(ascending=False).index

plt.figure(figsize=(12, 10))

# 서빙 분포
plt.subplot(2, 2, 1)
sns.countplot(x='servings', data=df_sample, order=servings_order)
plt.title('Distribution of servings')

# method_key 분포
plt.subplot(2, 2, 2)
sns.countplot(x='method_key', data=df_sample, order=method_key_order)
plt.title('Distribution of method_key')

# type_key 분포
plt.subplot(2, 2, 3)
sns.countplot(x='type_key', data=df_sample, order=type_key_order)
plt.title('Distribution of type_key')
plt.xticks(rotation=45)  # x축 레이블을 45도 회전

# spicy_level 분포
plt.subplot(2, 2, 4)
sns.countplot(x='spicy_level', data=df_sample, order=spicy_level_order)
plt.title('Distribution of spicy_level')

plt.tight_layout()
plt.show()
